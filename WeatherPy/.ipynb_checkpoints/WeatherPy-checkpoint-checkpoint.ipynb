# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observable trends:
# 1. Latitude between 0 and 20 tend to have peak temperature levels, as shown in the first scatter plot of latitude versus temperature. This suggests that towards the center of the equator, countries will be warmer in weather.
#
# 2. The northern hemisphere shows a gradual increase in temperature as latitude decreases, as shown in the northern hemisphere max temp. versus latitude graph. This suggests that as you go further towards the equator, the temperature does get warmer.
#
# 3. The southern hemisphere shows a gradual increase in temperature as latitude increases, as shown in the southern hemisphere max temp. versus latitude graph. This further suggests that as you go further towards the equator, the temperature does get warmer.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 654

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_df = pd.read_csv("../output_data/cities.csv")

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

for city in cities:
    response = requests.get(query_url + city).json()
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
try:
    print(f"Beginning Data Retrieval")
    print(f"----------------------------")
    print(f"{cities}")    
        
except (KeyError, IndexError):
    print("City not found. Skipping...")
        
print("------------")
print("Data Retieval Complete")
print("------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.read_csv("../output_data/cities.csv")
weather_df = {"City":cities}
weather_df = pd.DataFrame(city_df)
weather_df.count()

#weather_df =‘python-api-challenge/WeatherPy’
 #with open(weather_df,’r’, newline = ‘’) as f:
   #read = csv.writer(f, lineterminator = ‘\n’)
   #read.writerows(cities)
#city_df = pd.read_csv("../output_data/cities.csv")
# Out:
# City_ID       548
# City          548
# Cloudiness    548
# Country       544
# Date          548
# Humidity      548
# Lat           548
# Lng           548
# Max Temp      548
# Wind Speed    548
# dtype: int64

# %%
#city_df = pd.read_csv("../output_data/cities.csv")
del city_df['City_ID']
city_df = city_df[['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date']]
city_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      ostrovnoy  68.05   39.51     37.50        72           2        7.16
# 1      mahebourg -20.41   57.70     78.80        74          75       11.41
# 2        qaanaaq  77.48  -69.36     22.20        73          25        2.37
# 3         zhuhai  40.71  112.04     44.60        39           0        4.47
# 4      cape town -33.93   18.42     55.99        76          20        8.05
# ..           ...    ...     ...       ...       ...         ...         ...
# 543       yabrud  33.97   36.66     80.60        32           0        8.05
# 544      paraiso  24.01 -104.61     84.20         4           5       16.11
# 545      veraval  49.65    0.71     61.00        62           0        8.05
# 546  novyy urgal  51.07  132.56     49.74        93         100        2.68
# 547      tongren  27.72  109.18     55.86        64           4        2.84
#
#     Country        Date
# 0        RU  1558378754
# ...

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
drop = city_df.drop(city_df[city_df.Humidity > 100].index, inplace=True)
print(drop)
city_df[["Lat", "Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Date"]].describe()
# Out:
# None
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    19.710402   20.861609   64.975119   67.265082   49.495430    8.657057
# std     33.637627   90.285396   18.721163   21.723477   36.887333    5.859917
# min    -54.810000 -173.230000    4.920000    4.000000    0.000000    0.540000
# 25%     -6.315000  -60.820000   53.940000   52.000000   14.000000    4.680000
# 50%     21.430000   21.550000   64.990000   71.000000   47.000000    7.000000
# 75%     47.895000  103.165000   80.600000   86.000000   81.000000   11.410000
# max     78.220000  179.320000  104.100000  100.000000  100.000000   46.080000
#
#                Date
# count  5.470000e+02
# mean   1.558379e+09
# std    7.826709e+01
# min    1.558378e+09
# 25%    1.558379e+09
# 50%    1.558379e+09
# 75%    1.558379e+09
# max    1.558379e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidover = city_df['Humidity']>100
print(humidover)
print(humidover.shape)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# Name: Humidity, Length: 547, dtype: bool
# (547,)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#NEED TO FINISH THIS STEP

# %%
# Extract relevant fields from the data frame
#summary = ["City", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed","Date"]
#cities = city_df['City'].values

# Export the City_Data into a csv
city_df.to_csv('new.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (7/18/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CityLatitudeVSMaxTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (7/18/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CityLatitudeVSHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (7/18/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CityLatitudeVSCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (7/18/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CityLatitudeVSWindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

#Northern Hemisphere
north_df= city_df.loc[city_df['Lat'] > 0]
north_df.head()

#Southern Hemisphere 
south_df= city_df.loc[city_df['Lat'] < 0]
south_df.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1  mahebourg -20.41   57.70     78.80        74          75       11.41
# 4  cape town -33.93   18.42     55.99        76          20        8.05
# 5     atuona  -9.80 -139.03     81.96        76          78       16.49
# 6   flinders -34.58  150.85     60.01        62           0       11.41
# 7      opuwo -18.06   13.84     72.06        23           0        5.44
#
#   Country        Date
# 1      MU  1558378503
# 4      ZA  1558378755
# 5      PF  1558378755
# 6      AU  1558378755
# 7     NaN  1558378523

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Max Temp as x and y values
x_values = north_df['Lat'].astype('float')
y_values = north_df['Max Temp'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-", line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.6644951847801386

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Max Temp as x and y values
x_values = south_df['Lat'].astype('float')
y_values = south_df['Max Temp'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.5880057276369802

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Humidty and Latitude as x and y values
x_values = north_df['Lat'].astype('float')
y_values = north_df['Humidity'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.010729512501511098

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Humidty and Latitude as x and y values
x_values = south_df['Lat'].astype('float')
y_values = south_df['Humidity'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.01299355637910035

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Cloudiness and Latitude as x and y values
x_values = north_df['Lat'].astype('float')
y_values = north_df['Cloudiness'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.007627485925231671

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Cloudiness and Latitude as x and y values
x_values = south_df['Lat'].astype('float')
y_values = south_df['Cloudiness'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.05294530205984339

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Wind Speed and Latitude as x and y values
x_values = north_df['Lat'].astype('float')
y_values = north_df['Wind Speed'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.011478610492563561

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Wind Speed and Latitude as x and y values
x_values = south_df['Lat'].astype('float')
y_values = south_df['Wind Speed'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-",line_eq)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.11293389416296586
